# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.0     ✔ purrr   0.3.4
# ✔ tibble  3.0.1     ✔ dplyr   0.8.5
# ✔ tidyr   1.0.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
load("arrests_analysis.RData")

# %%
arrests_analysis
# Out:
#         report_id arrest_date arrest_time arrest_type age sex race_raw
# 1       191811472 05/03/2019  17:00:00    Misdemeanor 23  F   Black
# 2         5614161 04/29/2019  10:40:00    Felony      41  M   LatinX
# 3         5806609 11/23/2019  18:30:00    Felony      23  F   LatinX
# 4         5615197 04/30/2019  06:15:00    Felony      27  M   Other
# 5         5615701 04/30/2019  11:00:00    Dependent    2  F   LatinX
# 6         5615929 04/30/2019  15:50:00    Felony      41  M   White
# 7       191521148 11/19/2019  08:00:00    Misdemeanor 39  F   LatinX
# 8         5804207 11/20/2019  14:10:00    Felony      45  F   White
# 9       190325179 11/23/2019  10:35:00    Infraction  20  M   Other Asian
# 10      191718652 11/15/2019  08:45:00    Misdemeanor 47  F   White
# 11      190325212 11/23/2019  13:15:00    Infraction  21  F   White
# 12        5808956 11/26/2019  16:00:00    Misdemeanor 32  M   LatinX
# 13      191424675 11/25/2019  07:43:00    Infraction  37  M   LatinX
# ...

# %%
glimpse(arrests_analysis)
# Out:
# Rows: 1,324,710
# Columns: 20
# $ report_id        <dbl> 191811472, 5614161, 5806609, 5615197, 5615701, 56159…
# $ arrest_date      <chr> "05/03/2019", "04/29/2019", "11/23/2019", "04/30/201…
# $ arrest_time      <time> 17:00:00, 10:40:00, 18:30:00, 06:15:00, 11:00:00, 1…
# $ arrest_type      <chr> "Misdemeanor", "Felony", "Felony", "Felony", "Depend…
# $ age              <dbl> 23, 41, 23, 27, 2, 41, 39, 45, 20, 47, 21, 32, 37, 2…
# $ sex              <chr> "F", "M", "F", "M", "F", "M", "F", "F", "M", "F", "F…
# $ race_raw         <chr> "Black", "LatinX", "LatinX", "Other", "LatinX", "Whi…
# $ race_cat         <chr> "Black", "LatinX", "LatinX", "Other", "LatinX", "Whi…
# $ charge           <chr> "653.22 PC", "211PC", "211PC", "459PC", "300(B)WIC",…
# $ charge_desc      <chr> NA, "ROBBERY", "ROBBERY", "BURGLARY", NA, "ADW W/FIR…
# $ chg_grp_cd       <dbl> NA, 3, 3, 5, NA, 4, NA, 3, 18, NA, 17, 13, 20, 22, 1…
# ...

# %%
summary(arrests_analysis)
# Out:
#    report_id         arrest_date        arrest_time       arrest_type
#  Min.   :        0   Length:1324710     Length:1324710    Length:1324710
#  1st Qu.:  3467824   Class :character   Class1:hms        Class :character
#  Median :  4780886   Mode  :character   Class2:difftime   Mode  :character
#  Mean   : 45870273                      Mode  :numeric
#  3rd Qu.:111320256
#  Max.   :992109853
#
#       age            sex              race_raw           race_cat
#  Min.   : 0.00   Length:1324710     Length:1324710     Length:1324710
#  1st Qu.:23.00   Class :character   Class :character   Class :character
#  Median :32.00   Mode  :character   Mode  :character   Mode  :character
#  Mean   :34.22
#  3rd Qu.:45.00
#  Max.   :97.00
#
#     charge          charge_desc          chg_grp_cd    chg_grp_desc
#  Length:1324710     Length:1324710     Min.   : 1.00   Length:1324710
#  Class :character   Class :character   1st Qu.:10.00   Class :character
# ...
